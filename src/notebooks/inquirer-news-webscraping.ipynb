# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import requests

# %%
search = "technology"
driver = webdriver.Firefox()
request = requests.get('https://www.inquirer.net/search/?q={0}'.format(search))
driver.get('https://www.inquirer.net/search/?q={0}'.format(search))
driver.implicitly_wait(20)
soup_level1 = BeautifulSoup(driver.page_source, 'html.parser')
body = soup_level1.find("div", "gsc-wrapper")
print(body)
# Out:
# <div class="gsc-wrapper"><div class="gsc-adBlock" style="height: auto;"><iframe allowtransparency="true" frameborder="0" id="master-1" marginheight="0" marginwidth="0" name='{"name":"master-1","master-1":{"personalizedAds":true,"cx":"partner-pub-3470805887229135:3785249262","fexp":"20606,17301182,17301184","gcsc":true,"masterNumber":1,"number":null,"pubId":"google-coop","query":"technology","role":"m","source":"gcsc","hl":"en","cpp":3,"position":"top","cseGoogleHosting":"partner","columns":1,"horizontalAlignment":"left","resultsPageQueryParam":"query","ie":"UTF-8","maxTop":4,"minTop":0,"oe":"UTF-8","type":"ads","linkTarget":"_top"}}' scrolling="no" src="https://cse.google.com/cse_v2/ads?adsafe=high&amp;pcsa=true&amp;cx=partner-pub-3470805887229135%3A3785249262&amp;fexp=20606%2C17301182%2C17301184&amp;client=google-coop&amp;q=technology&amp;r=m&amp;hl=en&amp;cpp=3&amp;type=0&amp;oe=UTF-8&amp;ie=UTF-8&amp;format=p4&amp;ad=p4&amp;nocache=1271684429408506&amp;num=0&amp;output=uds_ads_onl
# ...
